# %%
import pandas as pd
from pathlib import Path

# %%
services_df = pd.read_pickle(Path('../data/processed/dataframes/analysis-df-w-api-data.pkl'))

# %%
services_df.to_csv('tmp3.csv')#this was the AST Task Assignment file

# %%
services_df.head()
# Out:
#                                        organisation  \
# 0        Foreign, Commonwealth & Development Office
# 1                                       Home Office
# 2                                Insolvency Service
# 3  Department for Environment, Food & Rural Affairs
# 4                  Department for Work and Pensions
#
#                                             service  \
# 0        pay for certificates to get married abroad
# 1  ask a question about applying for settled status
# 2              claim for redundancy and monies owed
# 3                              comply with uk reach
# 4                                      tell us once
#
#                             historical_service_equiv  unique_clicks_2022  \
# 0  Notices of intended marriage civil partnership...                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# ...
